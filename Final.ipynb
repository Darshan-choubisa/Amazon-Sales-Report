# %%
# ══════════════════════════════════════════════════════════════════
#  FINAL INSIGHTS — AMAZON INDIA SALES ANALYSIS
# ══════════════════════════════════════════════════════════════════

import pandas as pd

df = pd.read_csv('amazon_cleaned.csv')

print("=" * 60)
print("   AMAZON INDIA SALES — KEY BUSINESS INSIGHTS")
print("=" * 60)

print("""
INSIGHT 1 — Overall Business Size
──────────────────────────────────
Total Orders  : 1,21,177
Total Revenue : ₹8.06 Crore
Avg Order     : ₹648 per order
Date Range    : April to June 2022

INSIGHT 2 — Best Performing Category
──────────────────────────────────────
'Set' is the #1 category with ₹3.79 Cr revenue
Even though Set & Kurta have equal order counts,
Set earns ₹833 avg vs Kurta ₹456 avg per order.
→ ACTION : Promote Sets more, higher return per order

INSIGHT 3 — Geography
──────────────────────
Top 3 states = Maharashtra, Karnataka, Telangana
These 3 states alone = 45% of total revenue
→ ACTION : Focus warehouse & delivery in these states

INSIGHT 4 — Cancellation Problem
──────────────────────────────────
8.9% orders are cancelled = ₹96 lakh lost revenue
'Set' category has highest cancellations
→ ACTION : Investigate why Sets get cancelled most

INSIGHT 5 — Delivery Status
─────────────────────────────
64% orders still show 'Shipped' (not confirmed delivered)
Only 23.7% show 'Delivered to Buyer'
→ ACTION : Improve last mile delivery tracking

INSIGHT 6 — Size Demand
────────────────────────
M and L are most ordered sizes combined = 44,843 orders
XS and 6XL have very low demand
→ ACTION : Never let M & L go out of stock

INSIGHT 7 — B2B Opportunity
─────────────────────────────
B2B = only 0.7% of orders BUT ₹55,000 avg order value
B2C = 99.3% of orders with ₹627 avg order value
→ ACTION : A small push in B2B = massive revenue jump

INSIGHT 8 — Fulfilment
────────────────────────
Amazon Fulfilled = 70% of orders
Merchant Fulfilled = 30% of orders
→ ACTION : Merchant orders likely have more complaints,
           push more sellers to use Amazon fulfilment

INSIGHT 9 — Peak Season
────────────────────────
May 2022 = peak month with ₹2.90 Cr revenue
June 2022 = dip to ₹2.42 Cr
→ ACTION : Stock up inventory before April every year

INSIGHT 10 — High Value Orders
────────────────────────────────
Orders above ₹1000 are mostly in Set & Western Dress
These are premium customers worth targeting separately
→ ACTION : Create a premium segment marketing strategy
""")

print("=" * 60)
print("   PROJECT SUMMARY")
print("=" * 60)
print(f"""
Dataset    : Amazon India Sales (Apr–Jun 2022)
Rows       : 1,21,177 (after cleaning)
Tools Used : Python, Pandas, Seaborn, Matplotlib, SQL
Files      : amazon_cleaned.csv, amazon_sales.db
Charts     : 10 charts saved as PNG
SQL        : 15 queries written and executed
""")
print("=" * 60)
# Out:
# ...
#    AMAZON INDIA SALES — KEY BUSINESS INSIGHTS
# ...
#
# INSIGHT 1 — Overall Business Size
# ──────────────────────────────────
# Total Orders  : 1,21,177
# Total Revenue : ₹8.06 Crore
# Avg Order     : ₹648 per order
# Date Range    : April to June 2022
#
# INSIGHT 2 — Best Performing Category
# ──────────────────────────────────────
# 'Set' is the #1 category with ₹3.79 Cr revenue
# Even though Set & Kurta have equal order counts,
# Set earns ₹833 avg vs Kurta ₹456 avg per order.
# → ACTION : Promote Sets more, higher return per order
#
# INSIGHT 3 — Geography
# ──────────────────────
# Top 3 states = Maharashtra, Karnataka, Telangana
# These 3 states alone = 45% of total revenue
# → ACTION : Focus warehouse & delivery in these states
#
# INSIGHT 4 — Cancellation Problem
# ──────────────────────────────────
# 8.9% orders are cancelled = ₹96 lakh lost revenue
# 'Set' category has highest cancellations
# → ACTION : Investigate why Sets get cancelled most
#
# INSIGHT 5 — Delivery Status
# ...
